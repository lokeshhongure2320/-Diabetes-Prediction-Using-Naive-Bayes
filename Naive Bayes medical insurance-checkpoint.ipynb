# %% [markdown]
# # Naive Bayes

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns  
from sklearn.naive_bayes import GaussianNB , MultinomialNB,BernoulliNB
from sklearn.metrics import classification_report,confusion_matrix,accuracy_score
import warnings
warnings.filterwarnings("ignore")

# %%
data = pd.read_excel("diabetes.xlsx")
data
# Out:
#       Glucose  BloodPressure  SkinThickness   Insulin       BMI  \
# 0    0.689970       0.208333         0.4375  0.000000  0.544355
# 1    0.306991       0.430556         0.3625  0.000000  0.356183
# 2    0.902736       0.402778         0.0000  0.000000  0.267473
# 3    0.702128       0.430556         0.2875  0.295481  0.396505
# 4    0.702128       0.069444         0.4375  0.528094  0.799731
# ..        ...            ...            ...       ...       ...
# 763  0.404255       0.569444         0.6000  0.565815  0.525538
# 764  0.531915       0.486111         0.3375  0.000000  0.630376
# 765  0.525836       0.513889         0.2875  0.352063  0.345430
# 766  0.556231       0.347222         0.0000  0.000000  0.450269
# 767  0.355623       0.486111         0.3875  0.000000  0.458333
#
#      DiabetesPedigreeFunction       Age  Outcome
# 0                    0.489305  0.637363        1
# 1                    0.243316  0.219780        0
# 2                    0.529412  0.681319        1
# 3                    0.079323  0.000000        0
# 4                    1.000000  0.263736        1
# ..                        ...       ...      ...
# 763                  0.082888  0.923077        0
# 764                  0.233512  0.131868        0
# 765                  0.148841  0.197802        0
# 766                  0.241533  0.571429        1
# 767                  0.211230  0.043956        0
#
# [768 rows x 8 columns]

# %%
x = data.drop('Outcome', axis=1)
y = data['Outcome']

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2)

# %%
from sklearn.linear_model import LogisticRegression

# %%
model = LogisticRegression()

# %%
model.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
y_pred = model.predict(x_test)

# %%
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix, roc_curve, auc

# %%
accuracy = accuracy_score(y_test, y_pred)
print("accuracy_score:",accuracy*100,"%")
# Out:
# accuracy_score: 72.07792207792207 %

# %%
clf_report = classification_report(y_test, y_pred)
print(clf_report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.75      0.87      0.81       103
#            1       0.62      0.41      0.49        51
#
#     accuracy                           0.72       154
#    macro avg       0.68      0.64      0.65       154
# weighted avg       0.71      0.72      0.70       154
